# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv("daily_trade_prices.csv")
data2=pd.read_csv("dim_customer.csv")
data3=pd.read_csv("dim_date.csv")
data4=pd.read_csv("dim_stock.csv")
data5=pd.read_csv("trades.csv")

# %%
data1.head()
# Out:
#          date      STK001      STK002     STK003     STK004      STK005  \
# 0  2023-01-02  130.215257  143.732847  10.829021  41.721087  145.478750
# 1  2023-01-03  127.931982  141.811103  10.840378  42.372205  150.451171
# 2  2023-01-04  126.531338  139.814796  10.824561  43.273956  150.121855
# 3  2023-01-05  127.837687  140.885311  10.874388  43.307331  154.264000
# 4  2023-01-06  127.140842  143.103993  11.212466  46.389494  151.434469
#
#        STK006      STK007      STK008      STK009  ...     STK011     STK012  \
# 0  136.613229  193.549026  154.597180  190.646814  ...  66.629920  30.019335
# 1  131.081439  189.433498  156.245870  188.642260  ...  67.403967        NaN
# 2  132.287593  185.192571  153.568772  199.054913  ...  65.541600  28.336211
# 3  127.534322  189.023341  155.642891         NaN  ...  66.558603  27.706730
# 4  125.356736  185.290655  155.942939  203.068155  ...  67.339732  27.283299
#
# ...

# %%
D1=data1.copy()

# %%
D1.drop_duplicates()
# Out:
#            date      STK001      STK002     STK003      STK004      STK005  \
# 0    2023-01-02  130.215257  143.732847  10.829021   41.721087  145.478750
# 1    2023-01-03  127.931982  141.811103  10.840378   42.372205  150.451171
# 2    2023-01-04  126.531338  139.814796  10.824561   43.273956  150.121855
# 3    2023-01-05  127.837687  140.885311  10.874388   43.307331  154.264000
# 4    2023-01-06  127.140842  143.103993  11.212466   46.389494  151.434469
# ..          ...         ...         ...        ...         ...         ...
# 499  2024-11-29   69.335735  331.246792  32.443219  128.916005  159.362224
# 500  2024-12-02   68.121566  324.090768  31.831272  130.281550  158.416309
# 501  2024-12-03         NaN  316.554680  31.933773  140.893661  151.128642
# 502  2024-12-04   65.273747  313.258772  31.968273  139.516773  156.136395
# 503  2024-12-05   64.339639  307.700591  32.013201  127.306615  141.354172
#
# ...

# %%
D1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    504 non-null    object
#  1   STK001  462 non-null    float64
#  2   STK002  504 non-null    float64
#  3   STK003  504 non-null    float64
#  4   STK004  450 non-null    float64
#  5   STK005  504 non-null    float64
#  6   STK006  504 non-null    float64
#  7   STK007  504 non-null    float64
#  8   STK008  504 non-null    float64
#  9   STK009  447 non-null    float64
#  10  STK010  504 non-null    float64
#  11  STK011  504 non-null    float64
#  12  STK012  468 non-null    float64
#  13  STK013  504 non-null    float64
#  14  STK014  504 non-null    float64
#  15  STK015  504 non-null    float64
#  16  STK016  504 non-null    float64
#  17  STK017  504 non-null    float64
#  18  STK018  504 non-null    float64
#  19  STK019  450 non-null    float64
# ...

# %%
D1.columns = D1.columns.str.lower().str.replace(' ', '_')

# %%
D1.isnull().sum()
# Out:
# date       0
# stk001    42
# stk002     0
# stk003     0
# stk004    54
# stk005     0
# stk006     0
# stk007     0
# stk008     0
# stk009    57
# stk010     0
# stk011     0
# stk012    36
# stk013     0
# stk014     0
# stk015     0
# stk016     0
# stk017     0
# stk018     0
# stk019    54
# stk020    57
# dtype: int64

# %%
D1[D1['stk001'].isnull()]
# Out:
#            date  stk001      stk002     stk003      stk004      stk005  \
# 25   2023-02-06     NaN  139.645509  12.463754         NaN  184.315628
# 35   2023-02-20     NaN  152.945957  12.918588   43.668706  198.015269
# 54   2023-03-17     NaN  169.813033  13.129659   43.318052  175.348558
# 59   2023-03-24     NaN  169.078060  13.886164   44.414762  140.217474
# 66   2023-04-04     NaN  164.951129  13.503512   41.451850  142.506101
# 101  2023-05-23     NaN  163.660903  15.878196   57.425953   85.404078
# 109  2023-06-02     NaN  158.277833  15.570337   54.865901   80.942538
# 133  2023-07-06     NaN  164.381940  15.489221   62.136499   81.434241
# 137  2023-07-12     NaN  166.498576  16.217905   66.810511   81.069681
# 142  2023-07-19     NaN  172.912633  16.349989   66.451512  100.721419
# 166  2023-08-22     NaN  174.168022  17.285849   58.993002   80.284669
# 167  2023-08-23     NaN  173.679235  17.364657         NaN   80.318233
# ...

# %%
D1['date']=pd.to_datetime(D1['date'])

# %%
D1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    504 non-null    datetime64[ns]
#  1   stk001  462 non-null    float64
#  2   stk002  504 non-null    float64
#  3   stk003  504 non-null    float64
#  4   stk004  450 non-null    float64
#  5   stk005  504 non-null    float64
#  6   stk006  504 non-null    float64
#  7   stk007  504 non-null    float64
#  8   stk008  504 non-null    float64
#  9   stk009  447 non-null    float64
#  10  stk010  504 non-null    float64
#  11  stk011  504 non-null    float64
#  12  stk012  468 non-null    float64
#  13  stk013  504 non-null    float64
#  14  stk014  504 non-null    float64
#  15  stk015  504 non-null    float64
#  16  stk016  504 non-null    float64
#  17  stk017  504 non-null    float64
#  18  stk018  504 non-null    float64
#  19  stk019  450 non-null    float64
# ...

# %%
sns.histplot(D1['stk001'],kde=True)
# Out:
# <Axes: xlabel='stk001', ylabel='Count'>

# %%
sns.boxplot(D1['stk001'])
# Out:
# <Axes: ylabel='stk001'>

# %%
Q1=D1['stk001'].quantile(0.25)
Q3=D1['stk001'].quantile(0.75)
IQR=Q3-Q1
lower1=Q1-1.5*IQR
upper1=Q3 + 1.5 * IQR

outliers=D1[(D1['stk001']<lower1) | (D1['stk001']>upper1)]
num_outliers=len(outliers)
print(num_outliers/len(D1)*100)
# Out:
# 10.515873015873016

# %%
D1["stk001"]=np.log1p(D1["stk001"])

# %%
sns.histplot(D1['stk001'],kde=True)
# Out:
# <Axes: xlabel='stk001', ylabel='Count'>

# %%
sns.boxplot(D1['stk001'])
# Out:
# <Axes: ylabel='stk001'>

# %%
Q1=D1['stk001'].quantile(0.25)
Q3=D1['stk001'].quantile(0.75)
IQR=Q3-Q1
lower11=Q1-1.5*IQR
upper11=Q3 + 1.5 * IQR

outliers=D1[(D1['stk001']<lower11) | (D1['stk001']>upper11)]
num_outliers=len(outliers)
print(num_outliers/len(D1)*100)
# Out:
# 2.1825396825396823

# %%
D1["stk001"].mean()
# Out:
# np.float64(4.221477329923283)

# %%
D1["stk001"].median()
# Out:
# 4.104304065699906

# %%
D1['stk001'].fillna(D1['stk001'].median(),inplace=True)
# Out:
# /tmp/ipython-input-4170178132.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   D1['stk001'].fillna(D1['stk001'].median(),inplace=True)

# %%
D1["stk001"].isnull().sum()
# Out:
# np.int64(0)

# %%
D1.isnull().sum()
# Out:
# date       0
# stk001     0
# stk002     0
# stk003     0
# stk004    54
# stk005     0
# stk006     0
# stk007     0
# stk008     0
# stk009    57
# stk010     0
# stk011     0
# stk012    36
# stk013     0
# stk014     0
# stk015     0
# stk016     0
# stk017     0
# stk018     0
# stk019    54
# stk020    57
# dtype: int64

# %%
sns.histplot(D1['stk004'],kde=True)
# Out:
# <Axes: xlabel='stk004', ylabel='Count'>

# %%
sns.boxplot(D1['stk004'])
# Out:
# <Axes: ylabel='stk004'>

# %%
Q1=D1['stk004'].quantile(0.25)
Q3=D1['stk004'].quantile(0.75)
IQR=Q3-Q1
lower2=Q1-1.5*IQR
upper2=Q3 + 1.5 * IQR

outliers=D1[(D1['stk004']<lower2) | (D1['stk004']>upper2)]
num_outliers=len(outliers)
print(num_outliers/len(D1)*100)
# Out:
# 1.7857142857142856

# %%
D1["stk004"].mean()
# Out:
# np.float64(70.07967867617438)

# %%
D1["stk004"].median()
# Out:
# 66.63967398039122

# %%
D1['stk004'].fillna(D1['stk004'].median(),inplace=True)
# Out:
# /tmp/ipython-input-1510432900.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   D1['stk004'].fillna(D1['stk004'].median(),inplace=True)

# %%
D1["stk004"].isnull().sum()
# Out:
# np.int64(0)

# %%
D1.isnull().sum()
# Out:
# date       0
# stk001     0
# stk002     0
# stk003     0
# stk004     0
# stk005     0
# stk006     0
# stk007     0
# stk008     0
# stk009    57
# stk010     0
# stk011     0
# stk012    36
# stk013     0
# stk014     0
# stk015     0
# stk016     0
# stk017     0
# stk018     0
# stk019    54
# stk020    57
# dtype: int64

# %%
sns.histplot(D1['stk009'],kde=True)
# Out:
# <Axes: xlabel='stk009', ylabel='Count'>

# %%
sns.boxplot(D1['stk009'])
# Out:
# <Axes: ylabel='stk009'>

# %%
Q1=D1['stk009'].quantile(0.25)
Q3=D1['stk009'].quantile(0.75)
IQR=Q3-Q1
lower4=Q1-1.5*IQR
upper4=Q3 + 1.5 * IQR

outliers=D1[(D1['stk009']<lower4) | (D1['stk009']>upper4)]
num_outliers=len(outliers)
print(num_outliers/len(D1)*100)
# Out:
# 0.3968253968253968

# %%
D1["stk009"].mean()
# Out:
# np.float64(385.8287316901889)

# %%
D1["stk009"].median()
# Out:
# 377.4543883637391

# %%
D1['stk009'].fillna(D1['stk009'].median(),inplace=True)
# Out:
# /tmp/ipython-input-921037375.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   D1['stk009'].fillna(D1['stk009'].median(),inplace=True)

# %%
D1["stk009"].isnull().sum()
# Out:
# np.int64(0)

# %%
D1.isnull().sum()
# Out:
# date       0
# stk001     0
# stk002     0
# stk003     0
# stk004     0
# stk005     0
# stk006     0
# stk007     0
# stk008     0
# stk009     0
# stk010     0
# stk011     0
# stk012    36
# stk013     0
# stk014     0
# stk015     0
# stk016     0
# stk017     0
# stk018     0
# stk019    54
# stk020    57
# dtype: int64

# %%
sns.histplot(D1['stk012'],kde=True)
# Out:
# <Axes: xlabel='stk012', ylabel='Count'>

# %%
sns.boxplot(D1['stk012'])
# Out:
# <Axes: ylabel='stk012'>

# %%
D1["stk012"].mean()
# Out:
# np.float64(14.127433065338723)

# %%
D1["stk012"].median()
# Out:
# 12.273065736691827

# %%
D1['stk012'].fillna(D1['stk012'].median(),inplace=True)
# Out:
# /tmp/ipython-input-2339484202.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   D1['stk012'].fillna(D1['stk012'].median(),inplace=True)

# %%
D1["stk012"].isnull().sum()
# Out:
# np.int64(0)

# %%
D1.isnull().sum()
# Out:
# date       0
# stk001     0
# stk002     0
# stk003     0
# stk004     0
# stk005     0
# stk006     0
# stk007     0
# stk008     0
# stk009     0
# stk010     0
# stk011     0
# stk012     0
# stk013     0
# stk014     0
# stk015     0
# stk016     0
# stk017     0
# stk018     0
# stk019    54
# stk020    57
# dtype: int64

# %%
sns.histplot(D1['stk019'],kde=True)
# Out:
# <Axes: xlabel='stk019', ylabel='Count'>

# %%
sns.boxplot(D1['stk019'])
# Out:
# <Axes: ylabel='stk019'>

# %%
Q1=D1['stk019'].quantile(0.25)
Q3=D1['stk019'].quantile(0.75)
IQR=Q3-Q1
lower5=Q1-1.5*IQR
upper5=Q3 + 1.5 * IQR

outliers=D1[(D1['stk019']<lower5) | (D1['stk019']>upper5)]
num_outliers=len(outliers)
print(num_outliers/len(D1)*100)
# Out:
# 4.166666666666666

# %%
D1["stk019"].mean()
# Out:
# np.float64(49.994599641219665)

# %%
D1["stk019"].median()
# Out:
# 45.97413933151209

# %%
D1['stk019'].fillna(D1['stk019'].median(),inplace=True)
# Out:
# /tmp/ipython-input-979270942.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   D1['stk019'].fillna(D1['stk019'].median(),inplace=True)

# %%
D1["stk019"].isnull().sum()
# Out:
# np.int64(0)

# %%
D1.isnull().sum()
# Out:
# date       0
# stk001     0
# stk002     0
# stk003     0
# stk004     0
# stk005     0
# stk006     0
# stk007     0
# stk008     0
# stk009     0
# stk010     0
# stk011     0
# stk012     0
# stk013     0
# stk014     0
# stk015     0
# stk016     0
# stk017     0
# stk018     0
# stk019     0
# stk020    57
# dtype: int64

# %%
sns.histplot(D1['stk020'],kde=True)
# Out:
# <Axes: xlabel='stk020', ylabel='Count'>

# %%
sns.boxplot(D1['stk020'])
# Out:
# <Axes: ylabel='stk020'>

# %%
D1["stk020"].mean()
# Out:
# np.float64(62.16824128834519)

# %%
D1["stk020"].median()
# Out:
# 58.30799966421868

# %%
D1['stk020'].fillna(D1['stk020'].median(),inplace=True)
# Out:
# /tmp/ipython-input-3171206949.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   D1['stk020'].fillna(D1['stk020'].median(),inplace=True)

# %%
D1["stk020"].isnull().sum()
# Out:
# np.int64(0)

# %%
D1.isnull().sum()
# Out:
# date      0
# stk001    0
# stk002    0
# stk003    0
# stk004    0
# stk005    0
# stk006    0
# stk007    0
# stk008    0
# stk009    0
# stk010    0
# stk011    0
# stk012    0
# stk013    0
# stk014    0
# stk015    0
# stk016    0
# stk017    0
# stk018    0
# stk019    0
# stk020    0
# dtype: int64

# %%
data2.head()
# Out:
#    customer_key  customer_id account_type  avg_trade_size_baseline
# 0             1            1       Retail               216.919900
# 1             2            2       Retail                71.936692
# 2             3            3       Retail               178.906048
# 3             4            4       Retail               214.291567
# 4             5            5       Retail               170.590392

# %%
D2=data2.copy()

# %%
D2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_key             5000 non-null   int64
#  1   customer_id              5000 non-null   int64
#  2   account_type             5000 non-null   object
#  3   avg_trade_size_baseline  5000 non-null   float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 156.4+ KB

# %%
D2.duplicated().sum()
# Out:
# np.int64(0)

# %%
D2.isnull().sum()
# Out:
# customer_key               0
# customer_id                0
# account_type               0
# avg_trade_size_baseline    0
# dtype: int64

# %%
sns.boxplot(D2["avg_trade_size_baseline"])
# Out:
# <Axes: ylabel='avg_trade_size_baseline'>

# %%
data3.head()
# Out:
#    date_key        date  day  month month_name  quarter  year  day_of_week  \
# 0  20230102  2023-01-02    2      1    January        1  2023            1
# 1  20230103  2023-01-03    3      1    January        1  2023            2
# 2  20230104  2023-01-04    4      1    January        1  2023            3
# 3  20230105  2023-01-05    5      1    January        1  2023            4
# 4  20230106  2023-01-06    6      1    January        1  2023            5
#
#     day_name  is_weekend  is_holiday
# 0     Monday       False       False
# 1    Tuesday       False       False
# 2  Wednesday       False       False
# 3   Thursday       False       False
# 4     Friday       False       False

# %%
D3=data3.copy()

# %%
D3.duplicated().sum()
# Out:
# np.int64(0)

# %%
D3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date_key     504 non-null    int64
#  1   date         504 non-null    object
#  2   day          504 non-null    int64
#  3   month        504 non-null    int64
#  4   month_name   504 non-null    object
#  5   quarter      504 non-null    int64
#  6   year         504 non-null    int64
#  7   day_of_week  504 non-null    int64
#  8   day_name     504 non-null    object
#  9   is_weekend   504 non-null    bool
#  10  is_holiday   504 non-null    bool
# dtypes: bool(2), int64(6), object(3)
# memory usage: 36.6+ KB

# %%
D3['date']=pd.to_datetime(D3['date'])

# %%
D3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date_key     504 non-null    int64
#  1   date         504 non-null    datetime64[ns]
#  2   day          504 non-null    int64
#  3   month        504 non-null    int64
#  4   month_name   504 non-null    object
#  5   quarter      504 non-null    int64
#  6   year         504 non-null    int64
#  7   day_of_week  504 non-null    int64
#  8   day_name     504 non-null    object
#  9   is_weekend   504 non-null    bool
#  10  is_holiday   504 non-null    bool
# dtypes: bool(2), datetime64[ns](1), int64(6), object(2)
# memory usage: 36.6+ KB

# %%
D3.isnull().sum()
# Out:
# date_key       0
# date           0
# day            0
# month          0
# month_name     0
# quarter        0
# year           0
# day_of_week    0
# day_name       0
# is_weekend     0
# is_holiday     0
# dtype: int64

# %%
data4.head()
# Out:
#    stock_key stock_ticker company_name liquidity_tier      sector  \
# 0          1       STK001  STK001 Corp            Low      Energy
# 1          2       STK002  STK002 Corp            Low    Consumer
# 2          3       STK003  STK003 Corp            Low  Technology
# 3          4       STK004  STK004 Corp            Low     Finance
# 4          5       STK005  STK005 Corp            Low      Energy
#
#            industry
# 0         Utilities
# 1            Retail
# 2          Software
# 3  Asset Management
# 4        Renewables

# %%
D4=data4.copy()

# %%
D4.duplicated().sum()
# Out:
# np.int64(0)

# %%
D4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   stock_key       20 non-null     int64
#  1   stock_ticker    20 non-null     object
#  2   company_name    20 non-null     object
#  3   liquidity_tier  20 non-null     object
#  4   sector          20 non-null     object
#  5   industry        20 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.1+ KB

# %%
D4.isnull().sum()
# Out:
# stock_key         0
# stock_ticker      0
# company_name      0
# liquidity_tier    0
# sector            0
# industry          0
# dtype: int64

# %%
data5.head()
# Out:
#    transaction_id   timestamp  customer_id stock_ticker transaction_type  \
# 0               1  2023-01-02         4747       STK002              BUY
# 1               2  2023-01-02         4747       STK004              BUY
# 2               3  2023-01-02          227       STK006              BUY
# 3               4  2023-01-02         4747       STK006              BUY
# 4               5  2023-01-02         3938       STK006              BUY
#
#    quantity  average_trade_size  cumulative_portfolio_value
# 0        15               15.00                     2155.99
# 1        68               41.50                     4993.03
# 2        49               49.00                     6694.05
# 3       503              195.33                    73709.48
# 4       203              203.00                    27732.49

# %%
D5=data5.copy()

# %%
D5.duplicated().sum()
# Out:
# np.int64(0)

# %%
D5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   transaction_id              10000 non-null  int64
#  1   timestamp                   10000 non-null  object
#  2   customer_id                 10000 non-null  int64
#  3   stock_ticker                10000 non-null  object
#  4   transaction_type            10000 non-null  object
#  5   quantity                    10000 non-null  int64
#  6   average_trade_size          10000 non-null  float64
#  7   cumulative_portfolio_value  10000 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 625.1+ KB

# %%
D5['timestamp']=pd.to_datetime(D5['timestamp'])

# %%
D5.isnull().sum()
# Out:
# transaction_id                0
# timestamp                     0
# customer_id                   0
# stock_ticker                  0
# transaction_type              0
# quantity                      0
# average_trade_size            0
# cumulative_portfolio_value    0
# dtype: int64

# %%
sns.histplot(D5['average_trade_size'],kde=True)
# Out:
# <Axes: xlabel='average_trade_size', ylabel='Count'>

# %%
sns.boxplot(D5["average_trade_size"])
# Out:
# <Axes: ylabel='average_trade_size'>

# %%
Q1=D5['average_trade_size'].quantile(0.25)
Q3=D5['average_trade_size'].quantile(0.75)
IQR=Q3-Q1
lower7=Q1-1.5*IQR
upper7=Q3 + 1.5 * IQR

outliers=D5[(D5['average_trade_size']<lower7) | (D5['average_trade_size']>upper7)]
num_outliers=len(outliers)
print(num_outliers/len(D5)*100)
# Out:
# 25.25

# %%
c1_D5=D5.copy()

# %%
c1_D5 = c1_D5[(c1_D5['average_trade_size'] >= lower7) & (c1_D5['average_trade_size'] <= upper7)]

# %%
sns.boxplot(c1_D5['average_trade_size'])
# Out:
# <Axes: ylabel='average_trade_size'>

# %%
sns.histplot(c1_D5['average_trade_size'],kde=True)
# Out:
# <Axes: xlabel='average_trade_size', ylabel='Count'>

# %%
c2_D5=D5.copy()

# %%
c2_D5['average_trade_size'] = c2_D5['average_trade_size'].clip(lower7, upper7)

# %%
sns.histplot(c2_D5['average_trade_size'],kde=True)
# Out:
# <Axes: xlabel='average_trade_size', ylabel='Count'>

# %%
sns.boxplot(c2_D5['average_trade_size'])
# Out:
# <Axes: ylabel='average_trade_size'>

# %%
c3_D5=D5.copy()

# %%
median_val = c3_D5['average_trade_size'].median()

c3_D5.loc[(c3_D5['average_trade_size'] < lower7) | (c3_D5['average_trade_size'] > upper7),
       'average_trade_size'] = median_val

# %%
sns.histplot(c3_D5['average_trade_size'],kde=True)
# Out:
# <Axes: xlabel='average_trade_size', ylabel='Count'>

# %%
sns.boxplot(c3_D5['average_trade_size'])
# Out:
# <Axes: ylabel='average_trade_size'>

# %%
c4_D5=D5.copy()

# %%
from scipy.stats.mstats import winsorize
c4_D5["average_trade_size"] = winsorize(c4_D5['average_trade_size'], limits=[0.05, 0.05])

# %%
sns.histplot(c4_D5['average_trade_size'],kde=True)
# Out:
# <Axes: xlabel='average_trade_size', ylabel='Count'>

# %%
sns.boxplot(c4_D5['average_trade_size'])
# Out:
# <Axes: ylabel='average_trade_size'>

# %%
c5_D5=D5.copy()

# %%
from scipy.stats.mstats import winsorize

c5_D5['average_trade_size'] = winsorize(c5_D5['average_trade_size'], limits=[0.10, 0.10])

# %%
sns.histplot(c5_D5['average_trade_size'],kde=True)
# Out:
# <Axes: xlabel='average_trade_size', ylabel='Count'>

# %%
sns.boxplot(c5_D5['average_trade_size'])
# Out:
# <Axes: ylabel='average_trade_size'>

# %%
from scipy.stats.mstats import winsorize

D5['average_trade_size'] = winsorize(D5['average_trade_size'], limits=[0.10, 0.10])

# %%
sns.boxplot(D5['average_trade_size'])
# Out:
# <Axes: ylabel='average_trade_size'>

# %%
sns.histplot(D5['average_trade_size'],kde=True)
# Out:
# <Axes: xlabel='average_trade_size', ylabel='Count'>

# %% [markdown]
# Merge

# %%
D1.head()
# Out:
#         date    stk001      stk002     stk003     stk004      stk005  \
# 0 2023-01-02  4.876839  143.732847  10.829021  41.721087  145.478750
# 1 2023-01-03  4.859285  141.811103  10.840378  42.372205  150.451171
# 2 2023-01-04  4.848362  139.814796  10.824561  43.273956  150.121855
# 3 2023-01-05  4.858553  140.885311  10.874388  43.307331  154.264000
# 4 2023-01-06  4.853130  143.103993  11.212466  46.389494  151.434469
#
#        stk006      stk007      stk008      stk009  ...     stk011     stk012  \
# 0  136.613229  193.549026  154.597180  190.646814  ...  66.629920  30.019335
# 1  131.081439  189.433498  156.245870  188.642260  ...  67.403967  12.273066
# 2  132.287593  185.192571  153.568772  199.054913  ...  65.541600  28.336211
# 3  127.534322  189.023341  155.642891  377.454388  ...  66.558603  27.706730
# 4  125.356736  185.290655  155.942939  203.068155  ...  67.339732  27.283299
#
#        stk013      stk014     stk015     stk016      stk017      stk018  \
# ...

# %%
D2.head()
# Out:
#    customer_key  customer_id account_type  avg_trade_size_baseline
# 0             1            1       Retail               216.919900
# 1             2            2       Retail                71.936692
# 2             3            3       Retail               178.906048
# 3             4            4       Retail               214.291567
# 4             5            5       Retail               170.590392

# %%
D3.head()
# Out:
#    date_key       date  day  month month_name  quarter  year  day_of_week  \
# 0  20230102 2023-01-02    2      1    January        1  2023            1
# 1  20230103 2023-01-03    3      1    January        1  2023            2
# 2  20230104 2023-01-04    4      1    January        1  2023            3
# 3  20230105 2023-01-05    5      1    January        1  2023            4
# 4  20230106 2023-01-06    6      1    January        1  2023            5
#
#     day_name  is_weekend  is_holiday
# 0     Monday       False       False
# 1    Tuesday       False       False
# 2  Wednesday       False       False
# 3   Thursday       False       False
# 4     Friday       False       False

# %%
D3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date_key     504 non-null    int64
#  1   date         504 non-null    datetime64[ns]
#  2   day          504 non-null    int64
#  3   month        504 non-null    int64
#  4   month_name   504 non-null    object
#  5   quarter      504 non-null    int64
#  6   year         504 non-null    int64
#  7   day_of_week  504 non-null    int64
#  8   day_name     504 non-null    object
#  9   is_weekend   504 non-null    bool
#  10  is_holiday   504 non-null    bool
# dtypes: bool(2), datetime64[ns](1), int64(6), object(2)
# memory usage: 36.6+ KB

# %%
D4.head()
# Out:
#    stock_key stock_ticker company_name liquidity_tier      sector  \
# 0          1       STK001  STK001 Corp            Low      Energy
# 1          2       STK002  STK002 Corp            Low    Consumer
# 2          3       STK003  STK003 Corp            Low  Technology
# 3          4       STK004  STK004 Corp            Low     Finance
# 4          5       STK005  STK005 Corp            Low      Energy
#
#            industry
# 0         Utilities
# 1            Retail
# 2          Software
# 3  Asset Management
# 4        Renewables

# %%
D5.head()
# Out:
#    transaction_id  timestamp  customer_id stock_ticker transaction_type  \
# 0               1 2023-01-02         4747       STK002              BUY
# 1               2 2023-01-02         4747       STK004              BUY
# 2               3 2023-01-02          227       STK006              BUY
# 3               4 2023-01-02         4747       STK006              BUY
# 4               5 2023-01-02         3938       STK006              BUY
#
#    quantity  average_trade_size  cumulative_portfolio_value
# 0        15              102.22                     2155.99
# 1        68              102.22                     4993.03
# 2        49              102.22                     6694.05
# 3       503              195.33                    73709.48
# 4       203              203.00                    27732.49

# %%
T1=D1.copy()

# %%
prices_long = T1.melt(  id_vars="date", var_name="stock_ticker", value_name="stock_price")

prices_long.head()
# Out:
#         date stock_ticker  stock_price
# 0 2023-01-02       stk001     4.876839
# 1 2023-01-03       stk001     4.859285
# 2 2023-01-04       stk001     4.848362
# 3 2023-01-05       stk001     4.858553
# 4 2023-01-06       stk001     4.853130

# %%
merged_1 = pd.merge( D5,D2, on="customer_id", how="left")

merged_1.head()
# Out:
#    transaction_id  timestamp  customer_id stock_ticker transaction_type  \
# 0               1 2023-01-02         4747       STK002              BUY
# 1               2 2023-01-02         4747       STK004              BUY
# 2               3 2023-01-02          227       STK006              BUY
# 3               4 2023-01-02         4747       STK006              BUY
# 4               5 2023-01-02         3938       STK006              BUY
#
#    quantity  average_trade_size  cumulative_portfolio_value  customer_key  \
# 0        15              102.22                     2155.99          4747
# 1        68              102.22                     4993.03          4747
# 2        49              102.22                     6694.05           227
# 3       503              195.33                    73709.48          4747
# 4       203              203.00                    27732.49          3938
#
#   account_type  avg_trade_size_baseline
# 0       Retail                57.231335
# ...

# %%
merged_1.shape
# Out:
# (10000, 11)

# %%
merged_1.isnull().mean()*100
# Out:
# transaction_id                0.0
# timestamp                     0.0
# customer_id                   0.0
# stock_ticker                  0.0
# transaction_type              0.0
# quantity                      0.0
# average_trade_size            0.0
# cumulative_portfolio_value    0.0
# customer_key                  0.0
# account_type                  0.0
# avg_trade_size_baseline       0.0
# dtype: float64

# %%
merged_1["timestamp"] = pd.to_datetime(merged_1["timestamp"])

# %%
merged_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   transaction_id              10000 non-null  int64
#  1   timestamp                   10000 non-null  datetime64[ns]
#  2   customer_id                 10000 non-null  int64
#  3   stock_ticker                10000 non-null  object
#  4   transaction_type            10000 non-null  object
#  5   quantity                    10000 non-null  int64
#  6   average_trade_size          10000 non-null  float64
#  7   cumulative_portfolio_value  10000 non-null  float64
#  8   customer_key                10000 non-null  int64
#  9   account_type                10000 non-null  object
#  10  avg_trade_size_baseline     10000 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(3)
# memory usage: 859.5+ KB

# %%
merged_1.head()
# Out:
#    transaction_id  timestamp  customer_id stock_ticker transaction_type  \
# 0               1 2023-01-02         4747       STK002              BUY
# 1               2 2023-01-02         4747       STK004              BUY
# 2               3 2023-01-02          227       STK006              BUY
# 3               4 2023-01-02         4747       STK006              BUY
# 4               5 2023-01-02         3938       STK006              BUY
#
#    quantity  average_trade_size  cumulative_portfolio_value  customer_key  \
# 0        15              102.22                     2155.99          4747
# 1        68              102.22                     4993.03          4747
# 2        49              102.22                     6694.05           227
# 3       503              195.33                    73709.48          4747
# 4       203              203.00                    27732.49          3938
#
#   account_type  avg_trade_size_baseline
# 0       Retail                57.231335
# ...

# %%
merged_2=pd.merge( merged_1,prices_long,left_on="timestamp",right_on="date",how="left")
merged_2.head()
# Out:
#    transaction_id  timestamp  customer_id stock_ticker_x transaction_type  \
# 0               1 2023-01-02         4747         STK002              BUY
# 1               1 2023-01-02         4747         STK002              BUY
# 2               1 2023-01-02         4747         STK002              BUY
# 3               1 2023-01-02         4747         STK002              BUY
# 4               1 2023-01-02         4747         STK002              BUY
#
#    quantity  average_trade_size  cumulative_portfolio_value  customer_key  \
# 0        15              102.22                     2155.99          4747
# 1        15              102.22                     2155.99          4747
# 2        15              102.22                     2155.99          4747
# 3        15              102.22                     2155.99          4747
# 4        15              102.22                     2155.99          4747
#
# ...

# %%
merged_2.isnull().mean()*100
# Out:
# transaction_id                0.0
# timestamp                     0.0
# customer_id                   0.0
# stock_ticker_x                0.0
# transaction_type              0.0
# quantity                      0.0
# average_trade_size            0.0
# cumulative_portfolio_value    0.0
# customer_key                  0.0
# account_type                  0.0
# avg_trade_size_baseline       0.0
# date                          0.0
# stock_ticker_y                0.0
# stock_price                   0.0
# dtype: float64

# %%
merged_3=pd.merge(merged_2,D3,on="date",how="left")
merged_3.head()
# Out:
#    transaction_id  timestamp  customer_id stock_ticker_x transaction_type  \
# 0               1 2023-01-02         4747         STK002              BUY
# 1               1 2023-01-02         4747         STK002              BUY
# 2               1 2023-01-02         4747         STK002              BUY
# 3               1 2023-01-02         4747         STK002              BUY
# 4               1 2023-01-02         4747         STK002              BUY
#
#    quantity  average_trade_size  cumulative_portfolio_value  customer_key  \
# 0        15              102.22                     2155.99          4747
# 1        15              102.22                     2155.99          4747
# 2        15              102.22                     2155.99          4747
# 3        15              102.22                     2155.99          4747
# 4        15              102.22                     2155.99          4747
#
#   account_type  ...  date_key day month  month_name  quarter  year  \
# ...

# %%
merged_3.isnull().mean()*100
# Out:
# transaction_id                0.0
# timestamp                     0.0
# customer_id                   0.0
# stock_ticker_x                0.0
# transaction_type              0.0
# quantity                      0.0
# average_trade_size            0.0
# cumulative_portfolio_value    0.0
# customer_key                  0.0
# account_type                  0.0
# avg_trade_size_baseline       0.0
# date                          0.0
# stock_ticker_y                0.0
# stock_price                   0.0
# date_key                      0.0
# day                           0.0
# month                         0.0
# month_name                    0.0
# quarter                       0.0
# year                          0.0
# day_of_week                   0.0
# day_name                      0.0
# is_weekend                    0.0
# is_holiday                    0.0
# dtype: float64

# %%
merged_4=pd.merge(merged_3,D4,left_on="stock_ticker_x",right_on="stock_ticker",how="left")
merged_4.head()
# Out:
#    transaction_id  timestamp  customer_id stock_ticker_x transaction_type  \
# 0               1 2023-01-02         4747         STK002              BUY
# 1               1 2023-01-02         4747         STK002              BUY
# 2               1 2023-01-02         4747         STK002              BUY
# 3               1 2023-01-02         4747         STK002              BUY
# 4               1 2023-01-02         4747         STK002              BUY
#
#    quantity  average_trade_size  cumulative_portfolio_value  customer_key  \
# 0        15              102.22                     2155.99          4747
# 1        15              102.22                     2155.99          4747
# 2        15              102.22                     2155.99          4747
# 3        15              102.22                     2155.99          4747
# 4        15              102.22                     2155.99          4747
#
# ...

# %%
merged_4.isnull().mean()*100
# Out:
# transaction_id                0.0
# timestamp                     0.0
# customer_id                   0.0
# stock_ticker_x                0.0
# transaction_type              0.0
# quantity                      0.0
# average_trade_size            0.0
# cumulative_portfolio_value    0.0
# customer_key                  0.0
# account_type                  0.0
# avg_trade_size_baseline       0.0
# date                          0.0
# stock_ticker_y                0.0
# stock_price                   0.0
# date_key                      0.0
# day                           0.0
# month                         0.0
# month_name                    0.0
# quarter                       0.0
# year                          0.0
# day_of_week                   0.0
# day_name                      0.0
# is_weekend                    0.0
# is_holiday                    0.0
# stock_key                     0.0
# stock_ticker                  0.0
# company_name                  0.0
# ...

# %%
merged_4.duplicated().sum()
# Out:
# np.int64(0)

# %%
merged_4.shape
# Out:
# (200000, 30)

# %%
print(merged_4.columns)
# Out:
# Index(['transaction_id', 'timestamp', 'customer_id', 'stock_ticker_x',
#        'transaction_type', 'quantity', 'average_trade_size',
#        'cumulative_portfolio_value', 'customer_key', 'account_type',
#        'avg_trade_size_baseline', 'date', 'stock_ticker_y', 'stock_price',
#        'date_key', 'day', 'month', 'month_name', 'quarter', 'year',
#        'day_of_week', 'day_name', 'is_weekend', 'is_holiday', 'stock_key',
#        'stock_ticker', 'company_name', 'liquidity_tier', 'sector', 'industry'],
#       dtype='object')

# %%
merged_4.isnull().sum()
# Out:
# transaction_id                0
# timestamp                     0
# customer_id                   0
# stock_ticker_x                0
# transaction_type              0
# quantity                      0
# average_trade_size            0
# cumulative_portfolio_value    0
# customer_key                  0
# account_type                  0
# avg_trade_size_baseline       0
# date                          0
# stock_ticker_y                0
# stock_price                   0
# date_key                      0
# day                           0
# month                         0
# month_name                    0
# quarter                       0
# year                          0
# day_of_week                   0
# day_name                      0
# is_weekend                    0
# is_holiday                    0
# stock_key                     0
# stock_ticker                  0
# company_name                  0
# liquidity_tier                0
# sector                        0
# ...

# %%
merged_4.drop(["customer_key","avg_trade_size_baseline","stock_ticker_x","cumulative_portfolio_value","date","stock_ticker_y","date_key","day","month","month_name","quarter","year","day_of_week","stock_key","company_name"],axis=1,inplace=True)

# %%
merged_4["total_trade_amount"] = merged_4["stock_price"] * merged_4["quantity"]

# %%
merged_4.head()
# Out:
#    transaction_id  timestamp  customer_id transaction_type  quantity  \
# 0               1 2023-01-02         4747              BUY        15
# 1               1 2023-01-02         4747              BUY        15
# 2               1 2023-01-02         4747              BUY        15
# 3               1 2023-01-02         4747              BUY        15
# 4               1 2023-01-02         4747              BUY        15
#
#    average_trade_size account_type  stock_price day_name  is_weekend  \
# 0              102.22       Retail     4.876839   Monday       False
# 1              102.22       Retail   143.732847   Monday       False
# 2              102.22       Retail    10.829021   Monday       False
# 3              102.22       Retail    41.721087   Monday       False
# 4              102.22       Retail   145.478750   Monday       False
#
#    is_holiday stock_ticker liquidity_tier    sector industry  \
# 0       False       STK002            Low  Consumer   Retail
# ...

# %%
merged_4.shape
# Out:
# (200000, 16)

# %%
sns.boxplot(merged_4['average_trade_size'])
# Out:
# <Axes: ylabel='average_trade_size'>

# %%
Q1=merged_4['average_trade_size'].quantile(0.25)
Q3=merged_4['average_trade_size'].quantile(0.75)
IQR=Q3-Q1
lowerr=Q1-1.5*IQR
upperr=Q3 + 1.5 * IQR

outliers=merged_4[(merged_4['average_trade_size']<lowerr) | (merged_4['average_trade_size']>upperr)]
num_outliers=len(outliers)
print(num_outliers/len(merged_4)*100)
# Out:
# 25.25

# %%
q1 = merged_4["average_trade_size"].quantile(0.01)
q99 = merged_4["average_trade_size"].quantile(0.99)
merged_4["average_trade_size"] = merged_4["average_trade_size"].clip(q1, q99)

# %%
Q1=merged_4['average_trade_size'].quantile(0.25)
Q3=merged_4['average_trade_size'].quantile(0.75)
IQR=Q3-Q1
lowerr1=Q1-1.5*IQR
upperr1=Q3 + 1.5 * IQR

outliers=merged_4[(merged_4['average_trade_size']<lowerr1) | (merged_4['average_trade_size']>upperr1)]
num_outliers=len(outliers)
print(num_outliers/len(merged_4)*100)
# Out:
# 25.25

# %%
merged_4["average_trade_size"]=np.log1p(merged_4["average_trade_size"])

# %%
Q1=merged_4['average_trade_size'].quantile(0.25)
Q3=merged_4['average_trade_size'].quantile(0.75)
IQR=Q3-Q1
lowerr2=Q1-1.5*IQR
upperr2=Q3 + 1.5 * IQR

outliers=merged_4[(merged_4['average_trade_size']<lowerr2) | (merged_4['average_trade_size']>upperr2)]
num_outliers=len(outliers)
print(num_outliers/len(merged_4)*100)
# Out:
# 25.019999999999996

# %%
merged_4['average_trade_size']=merged_4['average_trade_size'].clip(lowerr2,upperr2)

# %%
Q1=merged_4['average_trade_size'].quantile(0.25)
Q3=merged_4['average_trade_size'].quantile(0.75)
IQR=Q3-Q1
lowerr3=Q1-1.5*IQR
upperr3=Q3 + 1.5 * IQR

outliers=merged_4[(merged_4['average_trade_size']<lowerr3) | (merged_4['average_trade_size']>upperr3)]
num_outliers=len(outliers)
print(num_outliers/len(merged_4)*100)
# Out:
# 0.0

# %%
sns.boxplot(merged_4['average_trade_size'])
# Out:
# <Axes: ylabel='average_trade_size'>

# %%
sns.histplot(merged_4['average_trade_size'],kde=True)
# Out:
# <Axes: xlabel='average_trade_size', ylabel='Count'>

# %%
sns.boxplot(merged_4['stock_price'])
# Out:
# <Axes: ylabel='stock_price'>

# %%
sns.histplot(merged_4['stock_price'],kde=True)
# Out:
# <Axes: xlabel='stock_price', ylabel='Count'>

# %%
Q1=merged_4['stock_price'].quantile(0.25)
Q3=merged_4['stock_price'].quantile(0.75)
IQR=Q3-Q1
lowerr4=Q1-1.5*IQR
upperr4=Q3 + 1.5 * IQR

outliers=merged_4[(merged_4['stock_price']<lowerr4) | (merged_4['stock_price']>upperr4)]
num_outliers=len(outliers)
print(num_outliers/len(merged_4)*100)
# Out:
# 7.2700000000000005

# %%
merged_4.head()
# Out:
#    transaction_id  timestamp  customer_id transaction_type  quantity  \
# 0               1 2023-01-02         4747              BUY        15
# 1               1 2023-01-02         4747              BUY        15
# 2               1 2023-01-02         4747              BUY        15
# 3               1 2023-01-02         4747              BUY        15
# 4               1 2023-01-02         4747              BUY        15
#
#    average_trade_size account_type  stock_price day_name  is_weekend  \
# 0            4.897799       Retail     4.876839   Monday       False
# 1            4.897799       Retail   143.732847   Monday       False
# 2            4.897799       Retail    10.829021   Monday       False
# 3            4.897799       Retail    41.721087   Monday       False
# 4            4.897799       Retail   145.478750   Monday       False
#
#    is_holiday stock_ticker liquidity_tier    sector industry  \
# 0       False       STK002            Low  Consumer   Retail
# ...

# %%
sns.boxplot(merged_4['quantity'])
# Out:
# <Axes: ylabel='quantity'>

# %%
Q1=merged_4['quantity'].quantile(0.25)
Q3=merged_4['quantity'].quantile(0.75)
IQR=Q3-Q1
lowerr5=Q1-1.5*IQR
upperr5=Q3 + 1.5 * IQR

outliers=merged_4[(merged_4['quantity']<lowerr5) | (merged_4['quantity']>upperr5)]
num_outliers=len(outliers)
print(num_outliers/len(merged_4)*100)
# Out:
# 7.6499999999999995

# %%
sns.boxplot(merged_4['total_trade_amount'])
# Out:
# <Axes: ylabel='total_trade_amount'>

# %%
Q1=merged_4["total_trade_amount"].quantile(0.25)
Q3=merged_4['total_trade_amount'].quantile(0.75)
IQR=Q3-Q1
lowerr6=Q1-1.5*IQR
upperr6=Q3 + 1.5 * IQR

outliers=merged_4[(merged_4['total_trade_amount']<lowerr6) | (merged_4['total_trade_amount']>upperr6)]
num_outliers=len(outliers)
print(num_outliers/len(merged_4)*100)
# Out:
# 9.394
